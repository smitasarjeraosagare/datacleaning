# %%
#importing libaries
#importing csv file

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\Users\DELL\Desktop\data.csv")

# %%
# raw data

# %%
data.head()
# Out:
#         FMID                                        MarketName  \
# 0  1018261.0   Caledonia Farmers Market Association - Danville
# 1  1018318.0                 Stearns Homestead Farmers' Market
# 2  1009364.0                 106 S. Main Street Farmers Market
# 3  1010691.0               10th Steet Community Farmers Market
# 4  1002454.0                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
data.plot(linestyle=':')

# %%
#checking missing data

# %%
missing=data.isnull().sum()

# %%
missing[missing>0]
# Out:
# FMID              4773
# MarketName        4773
# Website           8268
# Facebook          9448
# Twitter          12507
# Youtube          13345
# OtherMedia       12724
# street            5063
# city              4813
# County            5284
# State             4773
# zip               5710
# Season1Date       7931
# Season1Time       7766
# Season2Date      13054
# Season2Time      13064
# Season3Date      13429
# Season3Time      13432
# Season4Date      13506
# Season4Time      13506
# x                 4802
# y                 4802
# value               13
# Location         10929
# Credit            4773
# WIC               4773
# WICcash           4773
# SFMNP             4773
# SNAP              4773
# Organic           4773
# Bakedgoods        7650
# Cheese            7650
# Crafts            7650
# Flowers           7650
# Eggs              7650
# Seafood           7650
# Herbs             7650
# Vegetables        7650
# Honey             7650
# Jams              7650
# ...

# %%
print("FMID \n"+"")
# Out:
# FMID

# %%
print(data.columns)
# Out:
# Index([u'FMID', u'MarketName', u'Website', u'Facebook', u'Twitter', u'Youtube',
#        u'OtherMedia', u'street', u'city', u'County', u'State', u'zip',
#        u'Season1Date', u'Season1Time', u'Season2Date', u'Season2Time',
#        u'Season3Date', u'Season3Time', u'Season4Date', u'Season4Time', u'x',
#        u'y', u'value', u'Location', u'Credit', u'WIC', u'WICcash', u'SFMNP',
#        u'SNAP', u'Organic', u'Bakedgoods', u'Cheese', u'Crafts', u'Flowers',
#        u'Eggs', u'Seafood', u'Herbs', u'Vegetables', u'Honey', u'Jams',
#        u'Maple', u'Meat', u'Nursery', u'Nuts', u'Plants', u'Poultry',
#        u'Prepared', u'Soap', u'Trees', u'Wine', u'Coffee', u'Beans', u'Fruits',
#        u'Grains', u'Juices', u'Mushrooms', u'PetFood', u'Tofu',
#        u'WildHarvested', u'updateTime'],
#       dtype='object')

# %%
data.sample(10)
# Out:
#          FMID                                        MarketName  \
# 7485  1004085                         Terra Alta Farmers Market
# 6786  1000043     Schenectady County Farm Bureau Farmers Market
# 6747  1010606                 Sarasota Downtown Farmers' Market
# 7978  1003935       Valle Crucis Farmers Market at Mast General
# 6036  1004376                          Pittsboro Farmers Market
# 627   1001851                         Blanchard Farmers' Market
# 7694  1003002              Thibodaux Main Street Farmers Market
# 8380  1000458                                     West Orchards
# 3216  1010143  Greene Public Library Association Farmers Market
# 8637  1016807                    Woodford County Farmers Market
#
#                                                 Website  \
# 7485  http://www.wvfarmers.org/memberpages/gardenfre...
# 6786                                                NaN
# 6747                                                NaN
# ...

# %%
missing=data.isnull().sum()
missing[missing>0]
# Out:
# FMID              4773
# MarketName        4773
# Website           8268
# Facebook          9448
# Twitter          12507
# Youtube          13345
# OtherMedia       12724
# street            5063
# city              4813
# County            5284
# State             4773
# zip               5710
# Season1Date       7931
# Season1Time       7766
# Season2Date      13054
# Season2Time      13064
# Season3Date      13429
# Season3Time      13432
# Season4Date      13506
# Season4Time      13506
# x                 4802
# y                 4802
# value               13
# Location         10929
# Credit            4773
# WIC               4773
# WICcash           4773
# SFMNP             4773
# SNAP              4773
# Organic           4773
# Bakedgoods        7650
# Cheese            7650
# Crafts            7650
# Flowers           7650
# Eggs              7650
# Seafood           7650
# Herbs             7650
# Vegetables        7650
# Honey             7650
# Jams              7650
# ...

# %%
# calculating the missing data in%

# %%
tot_cells=np.product(data.shape)
tot_cells=float(tot_cells)

# %%
tot_missing=missing.sum()
tot_missing=float(tot_missing)

# %%
percent_missing= (tot_missing/tot_cells) * 100
percent_missing
# Out:
# 57.10676929149399

# %%
#Almost a half of the cells  data is missing

# %%
missing[0:10]
# Out:
# FMID           4773
# MarketName     4773
# Website        8268
# Facebook       9448
# Twitter       12507
# Youtube       13345
# OtherMedia    12724
# street         5063
# city           4813
# County         5284
# dtype: int64

# %%
missing[missing>0][0:20]
# Out:
# FMID            4773
# MarketName      4773
# Website         8268
# Facebook        9448
# Twitter        12507
# Youtube        13345
# OtherMedia     12724
# street          5063
# city            4813
# County          5284
# State           4773
# zip             5710
# Season1Date     7931
# Season1Time     7766
# Season2Date    13054
# Season2Time    13064
# Season3Date    13429
# Season3Time    13432
# Season4Date    13506
# Season4Time    13506
# dtype: int64

# %%
print (data.shape)
# Out:
# (13512, 60)

# %%
#drop duplicates

# %%
data.describe()
# Out:
#                FMID            x            y         value
# count  8.739000e+03  8710.000000  8710.000000  13499.000000
# mean   1.010664e+06   -90.929702    39.133834    285.688562
# std    5.532770e+04    17.369809     5.285895   3192.666847
# min    1.000001e+06  -166.540000    17.709900      0.000000
# 25%    1.003422e+06   -97.207537    36.243804      7.000000
# 50%    1.006893e+06   -86.250101    40.017753     16.100000
# 75%    1.010812e+06   -77.597483    42.417160     45.200000
# max    2.000036e+06   -64.704300    64.862750  80977.000000

# %%
data.drop_duplicates()
# Out:
#             FMID                                         MarketName  \
# 0      1018261.0    Caledonia Farmers Market Association - Danville
# 1      1018318.0                  Stearns Homestead Farmers' Market
# 2      1009364.0                  106 S. Main Street Farmers Market
# 3      1010691.0                10th Steet Community Farmers Market
# 4      1002454.0                               112st Madison Avenue
# 5      1011100.0                            12 South Farmers Market
# 6      1009845.0         125th Street Fresh Connect Farmers' Market
# 7      1005586.0                12th & Brandywine Urban Farm Market
# 8      1008071.0                               14&U Farmers' Market
# 9      1012710.0               14th & Kennedy Street Farmers Market
# 10     1019157.0                            16th Ave Farmers Market
# 11     1018792.0                                     170 Farm Stand
# 12     1016782.0                           175th Street Greenmarket
# ...

# %%
# Drop Missing values

# %%
columns_with_na_dropped = data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
print(data.shape)
columns_with_na_dropped.shape
# Out:
# (13512, 60)
# (13512, 0)

# %%
#replacing missing value with Nan

# %%
#filling

# %%
df = data.replace(np.nan, '', regex=True)

# %%
data.fillna(0)
# Out:
#             FMID                                         MarketName  \
# 0      1018261.0    Caledonia Farmers Market Association - Danville
# 1      1018318.0                  Stearns Homestead Farmers' Market
# 2      1009364.0                  106 S. Main Street Farmers Market
# 3      1010691.0                10th Steet Community Farmers Market
# 4      1002454.0                               112st Madison Avenue
# 5      1011100.0                            12 South Farmers Market
# 6      1009845.0         125th Street Fresh Connect Farmers' Market
# 7      1005586.0                12th & Brandywine Urban Farm Market
# 8      1008071.0                               14&U Farmers' Market
# 9      1012710.0               14th & Kennedy Street Farmers Market
# 10     1019157.0                            16th Ave Farmers Market
# 11     1018792.0                                     170 Farm Stand
# 12     1016782.0                           175th Street Greenmarket
# ...

# %%
data.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#             FMID                                         MarketName  \
# 0      1018261.0    Caledonia Farmers Market Association - Danville
# 1      1018318.0                  Stearns Homestead Farmers' Market
# 2      1009364.0                  106 S. Main Street Farmers Market
# 3      1010691.0                10th Steet Community Farmers Market
# 4      1002454.0                               112st Madison Avenue
# 5      1011100.0                            12 South Farmers Market
# 6      1009845.0         125th Street Fresh Connect Farmers' Market
# 7      1005586.0                12th & Brandywine Urban Farm Market
# 8      1008071.0                               14&U Farmers' Market
# 9      1012710.0               14th & Kennedy Street Farmers Market
# 10     1019157.0                            16th Ave Farmers Market
# 11     1018792.0                                     170 Farm Stand
# 12     1016782.0                           175th Street Greenmarket
# ...

# %%
data.fillna(method = 'pad', axis=0).fillna(0)
# Out:
#             FMID                                         MarketName  \
# 0      1018261.0    Caledonia Farmers Market Association - Danville
# 1      1018318.0                  Stearns Homestead Farmers' Market
# 2      1009364.0                  106 S. Main Street Farmers Market
# 3      1010691.0                10th Steet Community Farmers Market
# 4      1002454.0                               112st Madison Avenue
# 5      1011100.0                            12 South Farmers Market
# 6      1009845.0         125th Street Fresh Connect Farmers' Market
# 7      1005586.0                12th & Brandywine Urban Farm Market
# 8      1008071.0                               14&U Farmers' Market
# 9      1012710.0               14th & Kennedy Street Farmers Market
# 10     1019157.0                            16th Ave Farmers Market
# 11     1018792.0                                     170 Farm Stand
# 12     1016782.0                           175th Street Greenmarket
# ...

# %%
# Imputation

# %%
from sklearn.preprocessing import Imputer
my_imputer = Imputer()
n=data.copy()
n=n.select_dtypes(include=['int','float'])
imputed = my_imputer.fit_transform(n)
imputed
# Out:
# C:\Users\DELL\Anaconda2\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# array([[ 1.01826100e+06, -7.21403370e+01,  4.44110360e+01,
#          3.04000000e+01],
#        [ 1.01831800e+06, -8.17339387e+01,  4.13748009e+01,
#          3.96000000e+01],
#        [ 1.00936400e+06, -8.28187000e+01,  3.48042000e+01,
#          4.17000000e+01],
#        ...,
#        [ 1.01066357e+06, -9.09297019e+01,  3.91338342e+01,
#          1.27000000e+01],
#        [ 1.01066357e+06, -9.09297019e+01,  3.91338342e+01,
#          1.33000000e+01],
#        [ 1.01066357e+06, -9.09297019e+01,  3.91338342e+01,
#          1.20000000e+01]])

# %%
import numpy
print(numpy.isnan(imputed).sum())
# Out:
# 0

# %%
n.head(1)
# Out:
#         FMID          x          y  value
# 0  1018261.0 -72.140337  44.411036   30.4

# %%
imputed[0]
# Out:
# array([ 1.0182610e+06, -7.2140337e+01,  4.4411036e+01,  3.0400000e+01])

# %%
#Strategy = Median for nfl_data

# %%
my_imputer = Imputer(strategy='median')
n_med=data.copy()
n_med=n_med.select_dtypes(include=['int','float'])
n_med_imputed = my_imputer.fit_transform(n_med)
print(n.head(1))
print(n_med_imputed[0])
# Out:
#         FMID          x          y  value
# 0  1018261.0 -72.140337  44.411036   30.4
# [ 1.0182610e+06 -7.2140337e+01  4.4411036e+01  3.0400000e+01]
# C:\Users\DELL\Anaconda2\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Cleaning the Dataset

# %%
n_clean=n_med.fillna(n_med.median())
n_clean.head()
# Out:
#         FMID          x          y  value
# 0  1018261.0 -72.140337  44.411036   30.4
# 1  1018318.0 -81.733939  41.374801   39.6
# 2  1009364.0 -82.818700  34.804200   41.7
# 3  1010691.0 -94.274619  37.495628  195.8
# 4  1002454.0 -73.949300  40.793900  135.5

# %%
n_med.head()
# Out:
#         FMID          x          y  value
# 0  1018261.0 -72.140337  44.411036   30.4
# 1  1018318.0 -81.733939  41.374801   39.6
# 2  1009364.0 -82.818700  34.804200   41.7
# 3  1010691.0 -94.274619  37.495628  195.8
# 4  1002454.0 -73.949300  40.793900  135.5

# %%
#Adding Imputed Values to the table

# %%
n=xrange(0,20)  
# 'n' tracks the number of rows in the table. The number 20 should be replaced by the total number of rows in the table- nfl_med.shape[0]
col=list(n_med.columns)
m=xrange(0,33)
for m in m:
    for num in n:
        try:
            val=n_med_imputed[num][m]
            n_med[col[m]][num]=val
        except:
            pass
n_med.head()
# Out:
#         FMID          x          y  value
# 0  1018261.0 -72.140337  44.411036   30.4
# 1  1018318.0 -81.733939  41.374801   39.6
# 2  1009364.0 -82.818700  34.804200   41.7
# 3  1010691.0 -94.274619  37.495628  195.8
# 4  1002454.0 -73.949300  40.793900  135.5

# %%
# Correlation

# %%
corrmat=n_med.corr()
corrmat
# Out:
#            FMID         x         y     value
# FMID   1.000000  0.039986 -0.030355 -0.000126
# x      0.039986  1.000000  0.091718  0.002350
# y     -0.030355  0.091718  1.000000  0.012728
# value -0.000126  0.002350  0.012728  1.000000

# %%
n=xrange(0,20)  
# 'n' tracks the number of rows in the table. The number 20 should be replaced by the total number of rows in the table- nfl_med.shape[0]
col=list(n_med.columns)
m=xrange(0,33)
for m in m:
    for num in n:
        try:
            val=n_med_imputed[num][m]
            n_med[col[m]][num]=val
        except:
            pass
n_med.head()
# Out:
#         FMID          x          y  value
# 0  1018261.0 -72.140337  44.411036   30.4
# 1  1018318.0 -81.733939  41.374801   39.6
# 2  1009364.0 -82.818700  34.804200   41.7
# 3  1010691.0 -94.274619  37.495628  195.8
# 4  1002454.0 -73.949300  40.793900  135.5

# %%
#transformation or presention

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

corr = n_med.corr()


mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(250, 15, as_cmap=True,n=9,sep=20)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.7, center=0,
            square=True, linewidths=.5)

# %%
#Date Parsing

# %%
import datetime
data.head()
# Out:
#         FMID                                        MarketName  \
# 0  1018261.0   Caledonia Farmers Market Association - Danville
# 1  1018318.0                 Stearns Homestead Farmers' Market
# 2  1009364.0                 106 S. Main Street Farmers Market
# 3  1010691.0               10th Steet Community Farmers Market
# 4  1002454.0                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
k = 20 #number of variables for heatmap
cols = corrmat.nlargest(k, 'value')['value'].index
cm = np.corrcoef(n_clean[cols].values.T)
fig, ax = plt.subplots(figsize=(15,15))
sns.set(font_scale=1.45)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 13}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
sns.set(style="dark")

corr = n_med.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(250, 15, as_cmap=True,n=9,sep=20)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.7, center=0,
            square=True, linewidths=.5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13512 entries, 0 to 13511
# Data columns (total 60 columns):
# FMID             8739 non-null float64
# MarketName       8739 non-null object
# Website          5244 non-null object
# Facebook         4064 non-null object
# Twitter          1005 non-null object
# Youtube          167 non-null object
# OtherMedia       788 non-null object
# street           8449 non-null object
# city             8699 non-null object
# County           8228 non-null object
# State            8739 non-null object
# zip              7802 non-null object
# Season1Date      5581 non-null object
# Season1Time      5746 non-null object
# Season2Date      458 non-null object
# Season2Time      448 non-null object
# Season3Date      83 non-null object
# Season3Time      80 non-null object
# Season4Date      6 non-null object
# Season4Time      6 non-null object
# x                8710 non-null float64
# y                8710 non-null float64
# ...

# %%
null=data.isnull().sum()
null[null>0]
# Out:
# FMID              4773
# MarketName        4773
# Website           8268
# Facebook          9448
# Twitter          12507
# Youtube          13345
# OtherMedia       12724
# street            5063
# city              4813
# County            5284
# State             4773
# zip               5710
# Season1Date       7931
# Season1Time       7766
# Season2Date      13054
# Season2Time      13064
# Season3Date      13429
# Season3Time      13432
# Season4Date      13506
# Season4Time      13506
# x                 4802
# y                 4802
# value               13
# Location         10929
# Credit            4773
# WIC               4773
# WICcash           4773
# SFMNP             4773
# SNAP              4773
# Organic           4773
# Bakedgoods        7650
# Cheese            7650
# Crafts            7650
# Flowers           7650
# Eggs              7650
# Seafood           7650
# Herbs             7650
# Vegetables        7650
# Honey             7650
# Jams              7650
# ...

# %%
#Date Parsing

# %%
import datetime

# %%
data['Date_Parsed'] = pd.to_datetime(data['Season1Date'], format = "%m/%d/%y", errors='ignore',infer_datetime_format=True)
data["Date_Parsed"].head(20)
# Out:
# 0     06/14/2017 to 08/30/2017
# 1     06/24/2017 to 09/30/2017
# 2                          NaN
# 3     04/02/2014 to 11/30/2014
# 4             July to November
# 5     05/05/2015 to 10/27/2015
# 6     06/10/2014 to 11/25/2014
# 7     05/16/2014 to 10/17/2014
# 8     05/03/2014 to 11/22/2014
# 9     04/09/2016 to 11/19/2016
# 10    06/03/2018 to 10/28/2018
# 11    07/05/2017 to 11/22/2017
# 12    06/29/2017 to 11/22/2017
# 13           June to September
# 14              06/08/2017 to
# 15    06/01/2015 to 11/15/2015
# 16    06/07/2014 to 09/27/2014
# 17    05/20/2017 to 09/30/2017
# 18    09/03/2016 to 06/24/2017
# 19    01/01/2016 to 12/31/2016
# Name: Date_Parsed, dtype: object

# %%
day_of_month = data['Date_Parsed']
print(day_of_month.head())
# Out:
# 0    06/14/2017 to 08/30/2017
# 1    06/24/2017 to 09/30/2017
# 2                         NaN
# 3    04/02/2014 to 11/30/2014
# 4            July to November
# Name: Date_Parsed, dtype: object

# %%
day_of_month.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-d77e318e3e83> in <module>()
# ----> 1 day_of_month.isnull().sum()
#
# NameError: name 'day_of_month' is not defined

# %%
data['Date_Parsed'].value_counts().sort_values().plot.line()

# %%
data['Date_Parsed'].value_counts().resample('Y').sum().plot.line(..)
# Out:
#   File "<ipython-input-89-43eca474aa2a>", line 1
#     data['Date_Parsed'].value_counts().sum().plot.line(..)
#                                                        ^
# SyntaxError: invalid syntax

# %%
data['Date_Parsed'].value_counts().sort_values(ascending=False).head()
# Out:
# May to October              160
# 01/01/2014 to 12/31/2014    138
# 01/01/2016 to 12/31/2016    134
# 01/01/2015 to 12/31/2015    127
# June to October             126
# Name: Date_Parsed, dtype: int64

# %%
print(data['2014-01-01']
# Out:
#   File "<ipython-input-65-2753ed78ec21>", line 1
#     print(data['2014-01-01']
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
import chardet

with open("C:\Users\DELL\Desktop\data.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)
# Out:
# {'confidence': 1.0, 'language': '', 'encoding': 'ascii'}

# %%
data.head(5)
# Out:
#         FMID                                        MarketName  \
# 0  1018261.0   Caledonia Farmers Market Association - Danville
# 1  1018318.0                 Stearns Homestead Farmers' Market
# 2  1009364.0                 106 S. Main Street Farmers Market
# 3  1010691.0               10th Steet Community Farmers Market
# 4  1002454.0                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
data.dtypes
# Out:
# FMID             float64
# MarketName        object
# Website           object
# Facebook          object
# Twitter           object
# Youtube           object
# OtherMedia        object
# street            object
# city              object
# County            object
# State             object
# zip               object
# Season1Date       object
# Season1Time       object
# Season2Date       object
# Season2Time       object
# Season3Date       object
# Season3Time       object
# Season4Date       object
# Season4Time       object
# x                float64
# y                float64
# value            float64
# Location          object
# Credit            object
# WIC               object
# WICcash           object
# SFMNP             object
# SNAP              object
# Organic           object
#                   ...
# Cheese            object
# Crafts            object
# Flowers           object
# Eggs              object
# Seafood           object
# Herbs             object
# ...

# %%
data.sample(5)
# Out:
#             FMID                                 MarketName  \
# 7088   1007174.0  South Texas Farmers Market Association IV
# 10259        NaN                                        NaN
# 9738         NaN                                        NaN
# 7046   1017950.0                    South Haven Farm Market
# 11476        NaN                                        NaN
#
#                                Website Facebook Twitter Youtube OtherMedia  \
# 7088                               NaN      NaN     NaN     NaN        NaN
# 10259                              NaN      NaN     NaN     NaN        NaN
# 9738                               NaN      NaN     NaN     NaN        NaN
# 7046   http://Southhavenfarmmarket.com      NaN     NaN     NaN        NaN
# 11476                              NaN      NaN     NaN     NaN        NaN
#
#                          street         city     County  ... Beans Fruits  \
# 7088   1625 S. Zarzamora Street  San Antonio      Bexar  ...   NaN    NaN
# ...

# %%
# get all the unique values in the 'City' column
cities = data['city'].unique()

# sort them alphabetically and then take a closer look
cities.sort()
cities
# Out:
# array([nan, ' Buffalo', ' Cobleskill', ..., 'volcano', 'wheatland',
#        'woodstock'], dtype=object)

# %%
data['PetFood'] = data['PetFood'].str.lower()
# remove trailing white spaces
data['PetFood'] = data['PetFood'].str.strip()

# %%
import fuzzywuzzy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-72-8d8a7fd5f3e4> in <module>()
# ----> 1 import fuzzywuzzy
#
# ImportError: No module named fuzzywuzzy

# %%
data.head()
# Out:
#         FMID                                        MarketName  \
# 0  1018261.0   Caledonia Farmers Market Association - Danville
# 1  1018318.0                 Stearns Homestead Farmers' Market
# 2  1009364.0                 106 S. Main Street Farmers Market
# 3  1010691.0               10th Steet Community Farmers Market
# 4  1002454.0                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
d = data.values
print(X.shape, Y.shape)
# Out:
# ((13512L,), (13512L,))

# %%
thresholds =np.arange(0.0, 0.55, 0.05)

# %%
t =thresholds

# %%
plt.plot(thresholds)
